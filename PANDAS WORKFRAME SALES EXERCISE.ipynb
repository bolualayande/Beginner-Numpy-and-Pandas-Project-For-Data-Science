# %%
#This dataset contains a list of sales and movement data by item and department appended monthly 
#in Montgomery County of Maryland

# %%
#EXERCISE 1

# Import the necessary libraries (pandas).
# Load the Excel file into a Pandas DataFrame.
# Display the first 5 rows of the DataFrame.
# Display the basic statistics (mean, median, min, max, etc.) of the sales column.

# Find the total retail sale and warehouse sale generated.
# Display the warehouse sales in descending order.
# Find the item with the highest retail sales in the entire dataset.
# Add a new column named "Profit" that represents 10% of the retail sales and warehouse sales.

# %%
#EXERCISE 2

# How many rows and columns are there in the DataFrame?
# Display the column names of the DataFrame.
# Extract the data for the first 10 rows and display it.
# Extract the data for the last 5 rows and display it.

# %%
# QUESTION 1: Import the necessary libraries (pandas)

# %%
import numpy as np

# %%
import pandas as pd

# %%
# QUESTION 2: Load the Excel file into a Pandas DataFrame.

# %%
df = pd.read_csv ("C:\\Users\\23490\\Downloads\\Warehouse_and_Retail_Sales.csv")

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
# QUESTION 3:Display the first 5 rows of the DataFrame.

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
# QUESTION 4: Display the basic statistics (mean, median, min, max, etc.) of the sales column.

# %%
df.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307645.000000  307645.000000  307642.000000     307645.000000
# mean     2018.438525       6.423862       7.024071          6.936465
# std         1.083061       3.461812      30.986238         30.237195
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.267500          3.000000
# max      2020.000000      12.000000    2739.000000       1990.830000
#
#        WAREHOUSE SALES
# count    307645.000000
# mean         25.294597
# std         249.916798
# min       -7800.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %%
# QUESTION 5:Find the total revenue generated .

# %%
df[['RETAIL SALES', 'WAREHOUSE SALES']]
# Out:
#         RETAIL SALES  WAREHOUSE SALES
# 0               0.00             2.00
# 1               0.00             4.00
# 2               0.00             1.00
# 3               0.00             1.00
# 4               0.82             0.00
# ...              ...              ...
# 307640          0.00             5.00
# 307641         66.12           240.75
# 307642          2.25             0.00
# 307643         20.50             0.00
# 307644          0.00           -70.00
#
# [307645 rows x 2 columns]

# %%
total_sum = df['RETAIL SALES'].sum()

# %%
total_sum
# Out:
# 2160899.37

# %%
total_sum = df['WAREHOUSE SALES'].sum()

# %%
total_sum
# Out:
# 7781756.280000001

# %%
# QUESTION 6: Display the warehouse sales in descending order.

# %%
df = df.sort_values('WAREHOUSE SALES', ascending=False)

# %%
df
# Out:
#         YEAR  MONTH                  SUPPLIER ITEM CODE  \
# 13281   2020      7             CROWN IMPORTS     23445
# 234306  2019      7             CROWN IMPORTS     23445
# 209159  2019      5             CROWN IMPORTS     23445
# 104039  2017     11             CROWN IMPORTS     23445
# 48209   2017      6             CROWN IMPORTS     96750
# ...      ...    ...                       ...       ...
# 271062  2019     10  PREMIUM DISTRIBUTORS INC       175
# 62538   2017      8        ANHEUSER BUSCH INC       175
# 35931   2017      6        ANHEUSER BUSCH INC       175
# 89501   2017     10        ANHEUSER BUSCH INC       175
# 254100  2019      8                       NaN       600
#
#                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 13281   CORONA EXTRA LOOSE NR - 12OZ      BEER        1174.0
# 234306  CORONA EXTRA LOOSE NR - 12OZ      BEER        1198.0
# 209159  CORONA EXTRA LOOSE NR - 12OZ      BEER        1373.0
# ...

# %%
# QUESTION 7: Find the item with the highest retail sales in the entire dataset.

# %%
max_sales_index = df['RETAIL SALES'].idxmax()

# %%
max_sales_index
# Out:
# 12941

# %%
highest_retailsales_item = df.loc[max_sales_index, 'ITEM TYPE']

# %%
highest_retailsales_item
# Out:
# 'NON-ALCOHOL'

# %%
# QUESTION 8: Add a new column named "Profit" that represents 10% of the retail sales warehouse sales.

# %%
df['PROFIT FROM RETAIL SALES'] = 10/100 * df['RETAIL SALES']

# %%
df['PROFIT FROM WAREHOUSE SALES'] = 10/100 * df['WAREHOUSE SALES']

# %%
df.head()
# Out:
#         YEAR  MONTH       SUPPLIER ITEM CODE              ITEM DESCRIPTION  \
# 13281   2020      7  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 234306  2019      7  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 209159  2019      5  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 104039  2017     11  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 48209   2017      6  CROWN IMPORTS     96750   CORONA EXTRA 2/12 NR - 12OZ
#
#        ITEM TYPE  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES  \
# 13281       BEER        1174.0            1041.0         18317.00
# 234306      BEER        1198.0            1416.0         17810.87
# 209159      BEER        1373.0            1207.0         17703.62
# 104039      BEER         992.0             981.0         16079.12
# 48209       BEER          53.0              61.0         15955.46
#
#         PROFIT FROM RETAIL SALES  PROFIT FROM WAREHOUSE SALES
# ...

# %%
#EXERCISE 2

# %%
# QUESTION 1: How many rows and columns are there in the DataFrame?

# %%
df.shape
# Out:
# (307645, 9)

# %%
# QUESTION 2: Display the column names of the DataFrame.

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE, RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES, PROFIT FROM RETAIL SALES, PROFIT FROM WAREHOUSE SALES]
# Index: []

# %%
# QUESTION 3:Extract the data for the first 10 rows and display it.

# %%
df.head(10)
# Out:
#         YEAR  MONTH       SUPPLIER ITEM CODE              ITEM DESCRIPTION  \
# 13281   2020      7  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 234306  2019      7  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 209159  2019      5  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 104039  2017     11  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 48209   2017      6  CROWN IMPORTS     96750   CORONA EXTRA 2/12 NR - 12OZ
# 63417   2017      8  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 257614  2019      8  CROWN IMPORTS     96750   CORONA EXTRA 2/12 NR - 12OZ
# 222007  2019      6  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 259208  2019      9  CROWN IMPORTS     23445  CORONA EXTRA LOOSE NR - 12OZ
# 61238   2017      7  CROWN IMPORTS     96750   CORONA EXTRA 2/12 NR - 12OZ
#
#        ITEM TYPE  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES  \
# 13281       BEER        1174.0            1041.0         18317.00
# ...

# %%
# Question 4:Extract the data for the last 5 rows and display it.

# %%
df.tail()
# Out:
#         YEAR  MONTH                  SUPPLIER ITEM CODE  \
# 271062  2019     10  PREMIUM DISTRIBUTORS INC       175
# 62538   2017      8        ANHEUSER BUSCH INC       175
# 35931   2017      6        ANHEUSER BUSCH INC       175
# 89501   2017     10        ANHEUSER BUSCH INC       175
# 254100  2019      8                       NaN       600
#
#                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  RETAIL TRANSFERS  \
# 271062     EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0               0.0
# 62538      EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0               0.0
# 35931      EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0               0.0
# 89501      EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0               0.0
# 254100  ISTORE TRAINING OVERVIEW       REF           0.0               0.0
#
#         WAREHOUSE SALES  PROFIT FROM RETAIL SALES  PROFIT FROM WAREHOUSE SALES
# 271062          -4365.0                       0.0                       -436.5
# ...
